# %%
import pandas as pd
crunch = pd.read_csv('crunchyroll.csv')
# all_genres = crunch.genres
crunch.genres
# Out:
# 0       ['scifi', 'animation', 'action', 'comedy', 'cr...
# 1       ['scifi', 'war', 'animation', 'action', 'drama...
# 2               ['scifi', 'action', 'drama', 'animation']
# 3       ['scifi', 'animation', 'action', 'comedy', 'cr...
# 4               ['drama', 'action', 'scifi', 'animation']
#                               ...
# 1076                                  ['comedy', 'drama']
# 1077                              ['comedy', 'animation']
# 1078                                           ['comedy']
# 1079                              ['comedy', 'animation']
# 1080                     ['comedy', 'animation', 'music']
# Name: genres, Length: 1081, dtype: object

# %%
all_genres = crunch.genres
genres_list = []
for genres in all_genres:
    for genre in genres:
        print(genre)
        break

genres_list
# Out:
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# [
# ...
